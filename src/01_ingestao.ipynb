# %%
import json

import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine("sqlite:///../data/database.db")

with open("ingestoes.json", "r") as open_file:
    ingestoes = json.load(open_file)

for i in ingestoes:
    
    path = i['path']
    df = pd.read_csv(['path'], encoding='latin-1', sep=';')
    df.to_sql(i["table"], engine, if_exists="replace", index=False)

df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  23/06/2026   12:31:08         2024                2  Eleição Ordinária
# 1  23/06/2026   12:31:08         2024                2  Eleição Ordinária
# 2  23/06/2026   12:31:08         2024                2  Eleição Ordinária
# 3  23/06/2026   12:31:08         2024                2  Eleição Ordinária
# 4  23/06/2026   12:31:08         2024                2  Eleição Ordinária
#
#    CD_ELEICAO                DS_ELEICAO SG_UF  SG_UE           NM_UE  \
# 0         620  Eleições Municipais 2024    SP  66893            MAUÁ
# 1         619  Eleições Municipais 2024    BA  33839        BOTUPORÃ
# 2         619  Eleições Municipais 2024    BA  34550   CÍCERO DANTAS
# 3         619  Eleições Municipais 2024    RJ  58955     SÃO FIDÉLIS
# 4         619  Eleições Municipais 2024    SP  61751  ARTUR NOGUEIRA
#
#    SQ_CANDIDATO          NR_PROCESSO                      DS_TP_MOTIVO  \
# 0  250002154440  6004418820246260217  Fundamentos legais de julgamento
# 1   50002002469  6000567820246050168  Fundamentos legais de julgamento
# 2   50002067615  6002114820246050082  Fundamentos legais de julgamento
# 3  190002150093  6001747520246190035  Fundamentos legais de julgamento
# 4  250002371210  6007731420246260360  Fundamentos legais de julgamento
#
#                                           DS_MOTIVO
# 0     Inelegibilidade infraconstitucional(LC 64/90)
# 1     Inelegibilidade infraconstitucional(LC 64/90)
# 2             Ausência de condição de elegibilidade
# 3      Ausência de desincompatibilização (LC 64/90)
# 4  Desatendimento a requisito formal (Lei 9.504/97)
